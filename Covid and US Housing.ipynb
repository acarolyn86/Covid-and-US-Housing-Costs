# %% [markdown]
# ## COVID and the US Housing Crisis
#
# The cost of housing in the United States has gone up dramatically since the start of the Covid-19 pandemic, both for rentals and single family homes. Meanwhile, the availability of single family housing is lower than ever. The reasons for this lack of availability are many: the cost of building materials has skyrocketed; builders are not able to keep up with demand; and homes go under contract almost as soon as listing. The dream of home ownership is further out of reach for the average family, and even more so for individuals.
#
# This project will attempt to quantify the factors leading to the state of the housing market today. The project begins with an examination of how much housing costs have gone up during the pandemic, both at the state and metro level. It will look at housing inventory, including how much inventory has changed over time, and how long homes take to sell once on the market. All analyses use data available from Zillow, a real estate search service (https://www.zillow.com/research/data/).
#
# Zillow uses a methodology called Zillow Home Value Index (ZHVI), to calculate the typical home value for a given market, taking into account both location and seasonal adjustments. Data is published within a lower-tier (5th to 35th percentile), mid-tier (35th-65th percentile), and top-tier (65th to 95th percentile) range of home values. For the purposes of this project, the mid-tier data is used to represent the value of the average home for the middle-class.

# %%
#Importing libraries
import numpy as np
import pandas as pd

# %%
#Read in 4 files: home price by state, home price by metro, housing inventory, 
#and pending status (time for a home to go under contract)
home_state = pd.read_csv('State_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
home_metro = pd.read_csv('Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
inventory_metro = pd.read_csv('Metro_invt_fs_uc_sfrcondo_sm_month.csv') 
pending_metro = pd.read_csv('Metro_med_doz_pending_uc_sfrcondo_sm_month.csv')

# %%
#Information about the mid-tier home value by state
home_state.info()
home_state.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Columns: 275 entries, RegionID to 2022-06-30
# dtypes: float64(270), int64(2), object(3)
# memory usage: 109.7+ KB
#    RegionID  SizeRank  RegionName RegionType StateName  2000-01-31  \
# 0         9         0  California      State        CA    201873.0
# 1        54         1       Texas      State        TX    114777.0
# 2        43         2    New York      State        NY    150441.0
# 3        14         3     Florida      State        FL    116126.0
# 4        21         4    Illinois      State        IL    148565.0
#
#    2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  2021-09-30  \
# 0    202731.0    203810.0    206082.0    208517.0  ...    716941.0
# 1    114902.0    114942.0    115150.0    115199.0  ...    269194.0
# 2    151211.0    151854.0    153212.0    154439.0  ...    370157.0
# 3    116469.0    116832.0    117535.0    118205.0  ...    319849.0
# 4    148890.0    149334.0    150205.0    151102.0  ...    243117.0
#
#    2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    721951.0    727440.0    734241.0    744446.0    756574.0    771569.0
# 1    273492.0    277149.0    281437.0    286128.0    291601.0    297048.0
# 2    373228.0    376126.0    378994.0    382306.0    386106.0    390880.0
# 3    327258.0    334598.0    341431.0    349013.0    356969.0    366710.0
# 4    245371.0    247651.0    250176.0    252547.0    254932.0    257629.0
#
#    2022-04-30  2022-05-31  2022-06-30
# 0    786055.0    796986.0    799311.0
# 1    303127.0    308619.0    313339.0
# 2    395849.0    400971.0    405105.0
# 3    377432.0    388200.0    397280.0
# 4    260502.0    263716.0    266415.0
#
# [5 rows x 275 columns]

# %% [markdown]
# This dataset contains home values from the year 2000 to June 2022, but this project will only look at 2018 forward. Looking at data from 2018 to the present represents two "normal" years before the pandemic in 2020, and two years after. The same 2018-2020 time period will be used for the other datasets.
#
# Unexpectedly, the dataframe has 51 rows instead of 50, for 50 states. An examination of the RegionName column explains why:

# %%
print(home_state['RegionName'].unique())
# Out:
# ['California' 'Texas' 'New York' 'Florida' 'Illinois' 'Pennsylvania'
#  'Ohio' 'Michigan' 'Georgia' 'North Carolina' 'New Jersey' 'Virginia'
#  'Washington' 'Massachusetts' 'Indiana' 'Arizona' 'Tennessee' 'Missouri'
#  'Maryland' 'Wisconsin' 'Minnesota' 'Colorado' 'Alabama' 'South Carolina'
#  'Louisiana' 'Kentucky' 'Oregon' 'Oklahoma' 'Connecticut' 'Iowa'
#  'Mississippi' 'Arkansas' 'Kansas' 'Utah' 'Nevada' 'New Mexico'
#  'West Virginia' 'Nebraska' 'Idaho' 'Hawaii' 'Maine' 'New Hampshire'
#  'Rhode Island' 'Montana' 'Delaware' 'South Dakota' 'Alaska'
#  'North Dakota' 'Vermont' 'District of Columbia' 'Wyoming']

# %% [markdown]
# On a quick glance, the dataset includes housing data for Washington DC, which explains the extra row. This will be kept in the dataset, and in the other datasets, should it exist.
#
# Before looking further at the data, we will make the dataframe easier to work with by dropping all non-date columns, and turning the full state name into the row headers (the index). We will also limit our time frame to 2018 forward, as stated previously. Then we will check for missing (null) values, and values that do not make sense.

# %%
#Dropping non-date columns
home_state = home_state.drop(columns = ['RegionID','SizeRank','RegionType','StateName'])

#Setting the RegionName column to the index
home_state.set_index('RegionName',inplace=True)
home_state.columns = pd.to_datetime(home_state.columns)

#Using only 2018 data forward
home_state = home_state.loc[:,home_state.columns>='2018-01-31']
home_state.head(3)
# Out:
#             2018-01-31  2018-02-28  2018-03-31  2018-04-30  2018-05-31  \
# RegionName
# California    524332.0    529454.0    533849.0    537282.0    540032.0
# Texas         198850.0    199860.0    200905.0    201984.0    202990.0
# New York      289604.0    291009.0    292564.0    293987.0    295283.0
#
#             2018-06-30  2018-07-31  2018-08-31  2018-09-30  2018-10-31  ...  \
# RegionName                                                              ...
# California    542792.0    544534.0    545943.0    546844.0    548606.0  ...
# Texas         203985.0    204837.0    205812.0    206665.0    207606.0  ...
# New York      296518.0    297825.0    299224.0    300701.0    302030.0  ...
#
#             2021-09-30  2021-10-31  2021-11-30  2021-12-31  2022-01-31  \
# RegionName
# California    716941.0    721951.0    727440.0    734241.0    744446.0
# Texas         269194.0    273492.0    277149.0    281437.0    286128.0
# New York      370157.0    373228.0    376126.0    378994.0    382306.0
#
#             2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30
# RegionName
# California    756574.0    771569.0    786055.0    796986.0    799311.0
# Texas         291601.0    297048.0    303127.0    308619.0    313339.0
# New York      386106.0    390880.0    395849.0    400971.0    405105.0
#
# [3 rows x 54 columns]

# %%
#Check how many columns have null values
home_state.isna().any().sum()
# Out:
# 9

# %%
#Checking the null values
home_state.loc[home_state.isna().any(axis=1),home_state.isna().any(axis=0)]
# Out:
#                 2019-04-30  2020-08-31  2020-09-30  2020-10-31  2020-11-30  \
# RegionName
# Pennsylvania      195918.0         NaN    210186.0         NaN    215432.0
# North Carolina    204405.0    219778.0    221591.0    223664.0    225924.0
# Connecticut       261170.0         NaN         NaN    279407.0    284038.0
# Iowa              153319.0    158860.0    159318.0    159784.0    160709.0
# Arkansas          129584.0    136683.0    137461.0    138381.0    139561.0
# Kansas            154429.0    163339.0    164503.0    166023.0         NaN
# West Virginia     109469.0    113131.0    113511.0    114015.0    115024.0
# Idaho             276150.0    312878.0    317462.0    323821.0    331740.0
# Montana           280975.0    301076.0    303257.0    306344.0    310140.0
# South Dakota      211711.0    221924.0    222992.0    224370.0    226167.0
# Alaska                 NaN    289176.0    289077.0    290338.0    291237.0
# Wyoming           247534.0    262505.0    263304.0    264141.0    265444.0
#
#                 2021-01-31  2021-02-28  2021-03-31  2021-12-31
# RegionName
# Pennsylvania      220976.0    223442.0    225964.0    250716.0
# North Carolina         NaN    235114.0    238807.0    284415.0
# Connecticut       291728.0    296108.0    300672.0    335400.0
# Iowa                   NaN         NaN    166720.0    181196.0
# Arkansas               NaN    143998.0    145955.0    164183.0
# Kansas            172243.0    174599.0    176985.0    195034.0
# West Virginia     116908.0    117806.0    118840.0         NaN
# Idaho                  NaN    365133.0    377972.0    454341.0
# Montana                NaN    328053.0    334864.0    405374.0
# South Dakota           NaN         NaN         NaN    268860.0
# Alaska            296221.0    296628.0    296214.0    304548.0
# Wyoming           268937.0    271173.0    273745.0         NaN

# %% [markdown]
# There are few missing values in the dataframe, and it is best practice to avoid deleting needed data if possible. Interpolation can be used to fill in any missing values.

# %%
#Using interpolation, then rechecking number of columns with nulls
home_state.interpolate(method='linear',axis=1,limit=3,inplace=True)
home_state.isna().any().sum()
# Out:
# 0

# %% [markdown]
# Next, let's check for data that does not make sense. Since this is a dataset of home values nationally, a wide range can be expected. However, since these are typical mid-tier home values, extreme values, from anywhere near 0 or less or values of several million dollars, are unlikely.

# %%
home_state.describe()
# Out:
#           2018-01-31     2018-02-28     2018-03-31     2018-04-30  \
# count      51.000000      51.000000      51.000000      51.000000
# mean   242325.078431  243702.000000  244975.294118  246214.098039
# std    113356.385431  114242.134691  114797.677621  115253.543475
# min    105717.000000  106062.000000  106363.000000  106599.000000
# 25%    168113.000000  168932.500000  169412.500000  169779.500000
# 50%    228572.000000  229729.000000  230996.000000  232515.000000
# 75%    271524.000000  273603.500000  275345.500000  277656.500000
# max    641874.000000  644403.000000  647410.000000  648966.000000
#
#           2018-05-31     2018-06-30     2018-07-31     2018-08-31  \
# count      51.000000      51.000000      51.000000      51.000000
# mean   247307.882353  248403.725490  249440.686275  250395.764706
# std    115522.940516  116074.981297  116565.477150  116997.518664
# min    106729.000000  106792.000000  106807.000000  106802.000000
# 25%    170105.000000  170635.000000  171064.000000  171588.500000
# 50%    232790.000000  232374.000000  232201.000000  233357.000000
# 75%    279799.000000  282489.500000  284738.500000  287281.000000
# max    650269.000000  651714.000000  654047.000000  656736.000000
#
#           2018-09-30     2018-10-31  ...     2021-09-30     2021-10-31  \
# count      51.000000      51.000000  ...      51.000000      51.000000
# mean   251325.882353  252231.823529  ...  324407.882353  328150.274510
# std    117347.082817  117709.960621  ...  147746.143057  149434.266262
# min    107035.000000  107248.000000  ...  124295.000000  125232.000000
# 25%    172026.000000  172522.000000  ...  217616.500000  219444.000000
# 50%    234480.000000  235330.000000  ...  288276.000000  290835.000000
# 75%    289025.000000  290354.500000  ...  385556.500000  392619.500000
# max    658223.000000  659123.000000  ...  784049.000000  798344.000000
#
#           2021-11-30     2021-12-31     2022-01-31     2022-02-28  \
# count      51.000000      51.000000      51.000000      51.000000
# mean   331587.196078  335774.656863  340334.333333  345566.274510
# std    151002.938959  152368.185319  154152.284490  156468.374484
# min    126147.000000  128481.500000  130816.000000  133471.000000
# 25%    221045.500000  223614.500000  226550.500000  229608.000000
# 50%    293240.000000  298839.000000  304438.000000  309865.000000
# 75%    398514.000000  405315.000000  410752.500000  416998.500000
# max    811929.000000  822449.000000  833782.000000  847135.000000
#
#           2022-03-31     2022-04-30     2022-05-31     2022-06-30
# count      51.000000      51.000000      51.000000      51.000000
# mean   350421.372549  355393.176471  359671.333333  363108.431373
# std    159340.904579  162033.195234  164158.139863  164954.404978
# min    134494.000000  135729.000000  136566.000000  137379.000000
# 25%    231950.000000  234295.500000  236398.000000  238277.000000
# 50%    311242.000000  315132.000000  318170.000000  321497.000000
# 75%    423494.000000  431222.500000  436097.500000  441821.000000
# max    862489.000000  876786.000000  890452.000000  901942.000000
#
# [8 rows x 54 columns]

# %%
#Print minimum home value
print(home_state.describe().loc['min',:].min())

#Print maximum home value
print(home_state.describe().loc['max',:].max())
# Out:
# 105717.0
# 901942.0

# %% [markdown]
# The minimum home value in this dataset is close to 100,000 and the maximum is around 900,000. Those values are within an expected range.
#
# Now that the dataset is clean, an examination of 1) if there was an increase in the typical mid-tier home value, and 2) if so, how much, by state:

# %%
home_state_new = home_state.copy()

#Keep time period of 2018 forward
home_state.columns = pd.to_datetime(home_state.columns)
home_state_new = home_state_new.loc[:,~((home_state_new.columns>'2018-01-31') & (home_state_new.columns <'2022-06-30'))]

#Calculate price change and percent increase
home_state_new['Price Change'] = home_state_new.iloc[:,1]-home_state_new.iloc[:,0]
home_state_new['Overall_%_increase'] = round(((home_state_new.iloc[:,1]-home_state_new.iloc[:,0])/home_state_new.iloc[:,0])*100,2)
home_state_new.sort_values(by='Overall_%_increase',ascending=False,inplace=True)
home_state_new
# Out:
#                       2018-01-31 00:00:00  2022-06-30 00:00:00  Price Change  \
# RegionName
# Idaho                            235535.0             475113.0      239578.0
# Arizona                          236882.0             450629.0      213747.0
# Utah                             312983.0             577112.0      264129.0
# Florida                          228572.0             397280.0      168708.0
# Nevada                           270341.0             468427.0      198086.0
# Montana                          260898.0             448875.0      187977.0
# Georgia                          185582.0             316705.0      131123.0
# Tennessee                        175874.0             299571.0      123697.0
# North Carolina                   189048.0             320291.0      131243.0
# Washington                       372836.0             627555.0      254719.0
# Maine                            224476.0             362882.0      138406.0
# South Carolina                   180726.0             291591.0      110865.0
# New Hampshire                    272563.0             433627.0      161064.0
# Colorado                         374174.0             591189.0      217015.0
# New Mexico                       187018.0             294986.0      107968.0
# Texas                            198850.0             313339.0      114489.0
# Indiana                          141974.0             221019.0       79045.0
# Michigan                         155087.0             236980.0       81893.0
# California                       524332.0             799311.0      274979.0
# Oregon                           347162.0             527823.0      180661.0
# Ohio                             139031.0             211374.0       72343.0
# Alabama                          135585.0             205780.0       70195.0
# Rhode Island                     286678.0             434767.0      148089.0
# Missouri                         154307.0             229765.0       75458.0
# Wisconsin                        179050.0             263989.0       84939.0
# South Dakota                     198670.0             291501.0       92831.0
# Arkansas                         122861.0             178251.0       55390.0
# Massachusetts                    408996.0             592140.0      183144.0
# Kentucky                         136822.0             197413.0       60591.0
# Pennsylvania                     184379.0             265862.0       81483.0
# Nebraska                         166574.0             239574.0       73000.0
# Oklahoma                         125715.0             180690.0       54975.0
# New Jersey                       325964.0             467384.0      141420.0
# Vermont                          246453.0             352908.0      106455.0
# Delaware                         250482.0             356744.0      106262.0
# Minnesota                        237972.0             335407.0       97435.0
# Connecticut                      256064.0             360551.0      104487.0
# Kansas                           146141.0             205574.0       59433.0
# Hawaii                           641874.0             901942.0      260068.0
# New York                         289604.0             405105.0      115501.0
# Virginia                         270485.0             373341.0      102856.0
# Mississippi                      119263.0             164490.0       45227.0
# Wyoming                          235603.0             321497.0       85894.0
# Maryland                         303904.0             405414.0      101510.0
# Illinois                         200703.0             266415.0       65712.0
# Iowa                             146399.0             190902.0       44503.0
# West Virginia                    105717.0             137379.0       31662.0
# Louisiana                        169652.0             213658.0       44006.0
# Alaska                           269515.0             323820.0       54305.0
# District of Columbia             596679.0             714273.0      117594.0
# North Dakota                     232524.0             276315.0       43791.0
#
#                       Overall_%_increase
# RegionName
# Idaho                             101.72
# Arizona                            90.23
# Utah                               84.39
# Florida                            73.81
# Nevada                             73.27
# Montana                            72.05
# Georgia                            70.66
# Tennessee                          70.33
# North Carolina                     69.42
# Washington                         68.32
# Maine                              61.66
# South Carolina                     61.34
# New Hampshire                      59.09
# Colorado                           58.00
# New Mexico                         57.73
# Texas                              57.58
# Indiana                            55.68
# Michigan                           52.80
# California                         52.44
# Oregon                             52.04
# Ohio                               52.03
# Alabama                            51.77
# Rhode Island                       51.66
# Missouri                           48.90
# Wisconsin                          47.44
# South Dakota                       46.73
# Arkansas                           45.08
# Massachusetts                      44.78
# Kentucky                           44.28
# Pennsylvania                       44.19
# Nebraska                           43.82
# Oklahoma                           43.73
# New Jersey                         43.39
# Vermont                            43.19
# Delaware                           42.42
# Minnesota                          40.94
# Connecticut                        40.81
# Kansas                             40.67
# Hawaii                             40.52
# New York                           39.88
# Virginia                           38.03
# Mississippi                        37.92
# Wyoming                            36.46
# Maryland                           33.40
# Illinois                           32.74
# Iowa                               30.40
# West Virginia                      29.95
# Louisiana                          25.94
# Alaska                             20.15
# District of Columbia               19.71
# North Dakota                       18.83

# %% [markdown]
# As expected, the typical home value increased in all states between January 2018 and June 2022. However, the amount of the increase is significant, with the top eight states having an overall increase of over 70%. Even states with the smallest increases still saw a 20% increase in home values.
#
# Let's further break this down into a year by year percent increase, to see when the largest home value increases occured. Were they before or after the start of the pandemic?

# %%
#Percent increase in home value from year to year
home_state_yr = home_state.transpose()
home_state_yr = home_state_yr.groupby(home_state_yr.index.year,axis=0).mean()
home_state_yr = round(home_state_yr.pct_change()*100,2)
home_state_yr = home_state_yr.transpose()
home_state_yr
# Out:
#                       2018   2019   2020   2021   2022
# RegionName
# California             NaN   1.86   5.26  17.09  14.22
# Texas                  NaN   4.79   3.93  15.26  16.98
# New York               NaN   4.16   3.40  11.91   9.86
# Florida                NaN   4.73   4.83  17.09  22.99
# Illinois               NaN   2.04   2.14  11.06  10.06
# Pennsylvania           NaN   4.32   5.11  14.03   9.79
# Ohio                   NaN   5.95   6.42  14.49  10.97
# Michigan               NaN   6.24   5.76  14.72  11.03
# Georgia                NaN   6.62   5.50  17.06  19.59
# North Carolina         NaN   5.95   5.98  17.13  19.25
# New Jersey             NaN   2.35   3.95  15.49  10.76
# Virginia               NaN   3.90   4.42  11.86   9.42
# Washington             NaN   4.26   8.23  19.20  16.55
# Massachusetts          NaN   2.45   4.77  15.21  10.81
# Indiana                NaN   6.65   6.20  14.55  12.79
# Arizona                NaN   6.20   9.81  26.04  19.31
# Tennessee              NaN   6.09   6.97  16.36  19.36
# Missouri               NaN   5.04   5.10  14.20  11.68
# Maryland               NaN   2.32   3.25  12.67   8.09
# Wisconsin              NaN   5.45   6.02  13.42   9.82
# Minnesota              NaN   4.79   4.90  11.98   8.80
# Colorado               NaN   4.38   4.52  16.81  16.12
# Alabama                NaN   4.90   6.45  13.32  13.61
# South Carolina         NaN   4.91   4.93  14.43  18.57
# Louisiana              NaN   0.58   2.85   7.77   9.55
# Kentucky               NaN   4.72   5.32  11.94  11.25
# Oregon                 NaN   3.76   5.18  16.85  12.88
# Oklahoma               NaN   3.63   5.82  11.64  12.82
# Connecticut            NaN   1.21   3.71  16.97  10.35
# Iowa                   NaN   3.64   2.82   8.59   8.82
# Mississippi            NaN   4.14   3.64   9.72  11.44
# Arkansas               NaN   4.18   4.24  12.20  13.28
# Kansas                 NaN   4.31   4.77  12.93   9.38
# Utah                   NaN   7.81   7.50  23.70  18.95
# Nevada                 NaN   5.97   3.77  18.58  20.55
# New Mexico             NaN   5.67   6.83  15.98  13.72
# West Virginia          NaN   3.17   2.57   8.07  10.32
# Nebraska               NaN   5.44   5.00  12.57   9.98
# Idaho                  NaN  11.94  11.23  32.38  13.78
# Hawaii                 NaN   1.65   1.12  11.97  15.70
# Maine                  NaN   4.38   7.99  19.53  13.41
# New Hampshire          NaN   4.37   6.50  18.47  14.56
# Rhode Island           NaN   2.90   5.65  17.68  12.20
# Montana                NaN   5.66   6.00  20.80  19.29
# Delaware               NaN   2.76   3.17  14.36  11.56
# South Dakota           NaN   4.83   3.94  13.08  13.20
# Alaska                 NaN   5.56   1.81   3.34   4.58
# North Dakota           NaN   0.91   1.71   5.87   7.29
# Vermont                NaN   3.28   3.49  13.20  13.60
# District of Columbia   NaN   4.14   2.58   5.28   3.70
# Wyoming                NaN   4.79   4.37   7.73  11.23

# %%
#Average of all percent increases per year
home_state_yr.mean()
# Out:
# 2018          NaN
# 2019     4.426471
# 2020     4.930000
# 2021    14.442745
# 2022    12.898431
# dtype: float64

# %% [markdown]
# As seen above, there were small percent increases in the typical mid-tier home value from 2018-2020, with the overall average increase per year coming in at under 5%. Then from 2020-2022, there were dramatic increases for each state, in most cases double digits. This corresponds to an average percent increase of over 14% in 2021, which seems to be dropping in 2022. To further quantify this, how many states saw a double digit percent increase in home values each year?

# %%
print('2018-2019: ',home_state_yr.loc[home_state_yr.loc[:,2019] >= 10,:].shape[0])
print('2019-2020: ',home_state_yr.loc[home_state_yr.loc[:,2020] >= 10,:].shape[0])
print('2020-2021: ',home_state_yr.loc[home_state_yr.loc[:,2021] >= 10,:].shape[0])
print('2021-2022: ',home_state_yr.loc[home_state_yr.loc[:,2022] >= 10,:].shape[0])
# Out:
# 2018-2019:  1
# 2019-2020:  1
# 2020-2021:  43
# 2021-2022:  38

# %% [markdown]
# There is a stark difference between the number of states with double digit increases in home values pre- and post-start of the pandemic. The biggest increase came from 2020-2021, when 43 states saw double digit percent rise in their home values. In 2021-2022, increases occurred in 38 states, slightly down. In contrast, before 2020 this was only 1 state per year; that state was Idaho.
#
# It is likely the overall home values per state are much lower than those in the large metro areas in each state, where a high concentration of Americans live. Let's find the largest metro area in each state, and use that data to determine how the home values have increased in these areas.

# %%
#Get info about the metro home values file
home_metro.info()
home_metro.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Columns: 275 entries, RegionID to 2022-06-30
# dtypes: float64(270), int64(2), object(3)
# memory usage: 1.9+ MB
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  \
# 0       NaN    128454.0    128801.0    129167.0    129911.0    130662.0  ...
# 1        NY    225516.0    226863.0    228076.0    230462.0    232684.0  ...
# 2        CA    231193.0    231998.0    233231.0    235575.0    238089.0  ...
# 3        IL    171271.0    171675.0    172198.0    173245.0    174354.0  ...
# 4        TX    131555.0    131660.0    131748.0    131961.0    132186.0  ...
#
#    2021-09-30  2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# 0    311669.0    315805.0    319728.0    324103.0    328848.0    334078.0
# 1    567599.0    572173.0    575746.0    579000.0    582977.0    587634.0
# 2    846547.0    851306.0    858511.0    867810.0    878593.0    890931.0
# 3    285566.0    288245.0    290960.0    293700.0    296355.0    298940.0
# 4    329869.0    336001.0    341515.0    347444.0    354921.0    363495.0
#
#    2022-03-31  2022-04-30  2022-05-31  2022-06-30
# 0    339362.0    344931.0    349975.0    354165.0
# 1    594089.0    601248.0    608793.0    614826.0
# 2    908424.0    927686.0    944296.0    945642.0
# 3    302259.0    305752.0    309745.0    312752.0
# 4    371655.0    381221.0    389992.0    397605.0
#
# [5 rows x 275 columns]

# %% [markdown]
# In the first row is the data for the entirety of the US. Let's remove this, and check the rest of the RegionType column for any other variations.

# %%
#Dropping the first row to eliminate the national data
home_metro = home_metro.iloc[1:]

#Checking the RegionType column
home_metro.RegionType.value_counts()
# Out:
# Msa    907
# Name: RegionType, dtype: int64

# %% [markdown]
# The RegionType column shows the only data left is that of metro areas, but there are 907 of these. For the purposes of this project, only the largest metro in each state will be used. First, this dataframe will be formatted like the state-wide data, by turning the metro and state into the index, and dropping any non-date columns. Then we will check for any missing values before diving into the analysis.

# %%
#Remove state abbreviation from RegionName column
home_metro.loc[:,'RegionName'] = home_metro.loc[:,'RegionName'].str.split(',').str[0]

#Group by StateName, take largest metro area in each
home_metro.sort_values('SizeRank',inplace=True)
home_metro = home_metro.groupby(by='StateName',as_index=False).apply(lambda x:x.head(1))
home_metro.drop(columns=['SizeRank','RegionID','RegionType'],inplace=True)
home_metro.head(3)
# Out:
#         RegionName StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  \
# 0 133    Anchorage        AK    146009.0    146216.0    146383.0    146524.0
# 1 49    Birmingham        AL    121404.0    121840.0    121990.0    122203.0
# 2 76   Little Rock        AR     99370.0     99539.0     99738.0    100170.0
#
#        2000-05-31  2000-06-30  2000-07-31  2000-08-31  ...  2021-09-30  \
# 0 133    146797.0    146905.0    147338.0    147332.0  ...    326698.0
# 1 49     122785.0    123515.0    124301.0    124285.0  ...    218215.0
# 2 76     100548.0    100822.0    101011.0    101252.0  ...    176904.0
#
#        2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0 133    328546.0    326399.0    325473.0    324872.0    329512.0    332797.0
# 1 49     220738.0    223685.0    227239.0    230146.0    233254.0    235885.0
# 2 76     178642.0    181356.0    183713.0    186552.0    188429.0    189867.0
#
#        2022-04-30  2022-05-31  2022-06-30
# 0 133    340538.0    347338.0    356732.0
# 1 49     239441.0    242271.0    244871.0
# 2 76     191568.0    193482.0    195775.0
#
# [3 rows x 272 columns]

# %%
#Set location information as index
home_metro = home_metro.set_index(['RegionName','StateName'])

#Dates from 2018 forward
home_metro = home_metro.loc[:,home_metro.columns>='2018-01-31']
home_metro.head(3)
# Out:
#                        2018-01-31  2018-02-28  2018-03-31  2018-04-30  \
# RegionName  StateName
# Anchorage   AK           301388.0    301304.0    301109.0    300846.0
# Birmingham  AL           160026.0    160862.0    161223.0    162000.0
# Little Rock AR           145963.0    146118.0    146271.0    146615.0
#
#                        2018-05-31  2018-06-30  2018-07-31  2018-08-31  \
# RegionName  StateName
# Anchorage   AK           300899.0    301315.0    302334.0    302853.0
# Birmingham  AL           162910.0    163631.0    164555.0    165333.0
# Little Rock AR           146900.0    147164.0    147556.0    147838.0
#
#                        2018-09-30  2018-10-31  ...  2021-09-30  2021-10-31  \
# RegionName  StateName                          ...
# Anchorage   AK           302715.0    302286.0  ...    326698.0    328546.0
# Birmingham  AL           166489.0    167198.0  ...    218215.0    220738.0
# Little Rock AR           148229.0    148521.0  ...    176904.0    178642.0
#
#                        2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# RegionName  StateName
# Anchorage   AK           326399.0    325473.0    324872.0    329512.0
# Birmingham  AL           223685.0    227239.0    230146.0    233254.0
# Little Rock AR           181356.0    183713.0    186552.0    188429.0
#
#                        2022-03-31  2022-04-30  2022-05-31  2022-06-30
# RegionName  StateName
# Anchorage   AK           332797.0    340538.0    347338.0    356732.0
# Birmingham  AL           235885.0    239441.0    242271.0    244871.0
# Little Rock AR           189867.0    191568.0    193482.0    195775.0
#
# [3 rows x 54 columns]

# %%
#Check for missing values
home_metro.isna().any().sum()
# Out:
# 4

# %%
#Interpolate missing values then check again for nulls
home_metro = home_metro.interpolate(method='linear', axis=1,limit = 3)
home_metro.isna().any().sum()
# Out:
# 0

# %%
#Overall percent increase in home values
home_metro_new = home_metro.loc[:,['2018-01-31','2022-06-30']]
home_metro_new['Price Change']= home_metro_new.iloc[:,1]-home_metro_new.iloc[:,0]
home_metro_new['Overall % increase'] = round(100*(home_metro_new.iloc[:,1]-home_metro_new.iloc[:,0])/home_metro_new.iloc[:,0],2)
home_metro_new = home_metro_new.sort_values('Overall % increase',ascending = False)
home_metro_new
# Out:
#                                           2018-01-31  2022-06-30  \
# RegionName                     StateName
# Boise City                     ID           250890.0    517534.0
# Phoenix                        AZ           249637.0    482463.0
# Salt Lake City                 UT           335789.0    613471.0
# Charlotte                      NC           214549.0    386038.0
# Atlanta                        GA           216587.0    381361.0
# Las Vegas                      NV           259258.0    453682.0
# Nashville                      TN           262788.0    452102.0
# Dallas-Fort Worth              TX           237518.0    397605.0
# Indianapolis                   IN           165570.0    270516.0
# Miami-Fort Lauderdale          FL           279732.0    456489.0
# Seattle                        WA           487015.0    793263.0
# Albuquerque                    NM           193725.0    314431.0
# Portland                       ME           293920.0    476728.0
# Greenville                     SC           188839.0    301845.0
# Denver                         CO           411616.0    646474.0
# Manchester                     NH           285363.0    448008.0
# Cincinnati                     OH           169099.0    262158.0
# Birmingham                     AL           160026.0    244871.0
# Salisbury                      DE           250491.0    382278.0
# Detroit                        MI           161910.0    243922.0
# Providence                     RI           299572.0    449970.0
# Los Angeles-Long Beach-Anaheim CA           640354.0    945642.0
# Portland                       OR           398941.0    588722.0
# Milwaukee                      WI           185106.0    272038.0
# Billings                       MT           251323.0    368702.0
# Omaha                          NE           186349.0    272654.0
# Sioux Falls                    SD           210469.0    307538.0
# Trenton                        NJ           244490.0    355937.0
# Louisville-Jefferson County    KY           166148.0    240704.0
# Burlington                     VT           294932.0    424662.0
# Philadelphia                   PA           234298.0    336380.0
# Oklahoma City                  OK           151304.0    216826.0
# Wichita                        KS           133595.0    190677.0
# St. Louis                      MO           171057.0    243935.0
# Boston                         MA           468795.0    663494.0
# Minneapolis-St Paul            MN           269468.0    379145.0
# Jackson                        MS           133186.0    186318.0
# Cheyenne                       WY           265482.0    370268.0
# Virginia Beach                 VA           234812.0    325380.0
# Hartford                       CT           234988.0    322838.0
# Des Moines                     IA           196937.0    265878.0
# Washington                     DC           412302.0    556296.0
# New York                       NY           457946.0    614826.0
# Little Rock                    AR           145963.0    195775.0
# New Orleans                    LA           201474.0    269203.0
# Chicago                        IL           234278.0    312752.0
# Urban Honolulu                 HI           711522.0    937104.0
# Baltimore                      MD           288799.0    377062.0
# Huntington                     WV            98628.0    126746.0
# Fargo                          ND           229776.0    280810.0
# Anchorage                      AK           301388.0    356732.0
#
#                                           Price Change  Overall % increase
# RegionName                     StateName
# Boise City                     ID             266644.0              106.28
# Phoenix                        AZ             232826.0               93.27
# Salt Lake City                 UT             277682.0               82.70
# Charlotte                      NC             171489.0               79.93
# Atlanta                        GA             164774.0               76.08
# Las Vegas                      NV             194424.0               74.99
# Nashville                      TN             189314.0               72.04
# Dallas-Fort Worth              TX             160087.0               67.40
# Indianapolis                   IN             104946.0               63.38
# Miami-Fort Lauderdale          FL             176757.0               63.19
# Seattle                        WA             306248.0               62.88
# Albuquerque                    NM             120706.0               62.31
# Portland                       ME             182808.0               62.20
# Greenville                     SC             113006.0               59.84
# Denver                         CO             234858.0               57.06
# Manchester                     NH             162645.0               57.00
# Cincinnati                     OH              93059.0               55.03
# Birmingham                     AL              84845.0               53.02
# Salisbury                      DE             131787.0               52.61
# Detroit                        MI              82012.0               50.65
# Providence                     RI             150398.0               50.20
# Los Angeles-Long Beach-Anaheim CA             305288.0               47.67
# Portland                       OR             189781.0               47.57
# Milwaukee                      WI              86932.0               46.96
# Billings                       MT             117379.0               46.70
# Omaha                          NE              86305.0               46.31
# Sioux Falls                    SD              97069.0               46.12
# Trenton                        NJ             111447.0               45.58
# Louisville-Jefferson County    KY              74556.0               44.87
# Burlington                     VT             129730.0               43.99
# Philadelphia                   PA             102082.0               43.57
# Oklahoma City                  OK              65522.0               43.30
# Wichita                        KS              57082.0               42.73
# St. Louis                      MO              72878.0               42.60
# Boston                         MA             194699.0               41.53
# Minneapolis-St Paul            MN             109677.0               40.70
# Jackson                        MS              53132.0               39.89
# Cheyenne                       WY             104786.0               39.47
# Virginia Beach                 VA              90568.0               38.57
# Hartford                       CT              87850.0               37.38
# Des Moines                     IA              68941.0               35.01
# Washington                     DC             143994.0               34.92
# New York                       NY             156880.0               34.26
# Little Rock                    AR              49812.0               34.13
# New Orleans                    LA              67729.0               33.62
# Chicago                        IL              78474.0               33.50
# Urban Honolulu                 HI             225582.0               31.70
# Baltimore                      MD              88263.0               30.56
# Huntington                     WV              28118.0               28.51
# Fargo                          ND              51034.0               22.21
# Anchorage                      AK              55344.0               18.36

# %% [markdown]
# Even the smallest increase in the typical mid-tier home value was still over 18%, applying to the Anchorage, AK market. That translates to an increase of approximately $55,000 over the 4.5 year period.
#
# In contrast, the highest increase was the Boise, Idaho market, which saw home values double. A home buyer looking to save the full 20% for a downpayment would have needed around 50,000 dollars in 2018, but waiting a few years would see that amount go up to over 100,000.
#
# As an aside, we've looked at the home value increases, but which metro areas have the overall highest and the lowest home values as of mid-year 2022?

# %%
#Top 5 highest home values
home_metro_new.sort_values('2022-06-30',ascending=False).head()
# Out:
#                                           2018-01-31  2022-06-30  \
# RegionName                     StateName
# Los Angeles-Long Beach-Anaheim CA           640354.0    945642.0
# Urban Honolulu                 HI           711522.0    937104.0
# Seattle                        WA           487015.0    793263.0
# Boston                         MA           468795.0    663494.0
# Denver                         CO           411616.0    646474.0
#
#                                           Price Change  Overall % increase
# RegionName                     StateName
# Los Angeles-Long Beach-Anaheim CA             305288.0               47.67
# Urban Honolulu                 HI             225582.0               31.70
# Seattle                        WA             306248.0               62.88
# Boston                         MA             194699.0               41.53
# Denver                         CO             234858.0               57.06

# %%
#Lowest 5 home values
home_metro_new.sort_values('2022-06-30',ascending=False).tail()
# Out:
#                          2018-01-31  2022-06-30  Price Change  \
# RegionName    StateName
# Oklahoma City OK           151304.0    216826.0       65522.0
# Little Rock   AR           145963.0    195775.0       49812.0
# Wichita       KS           133595.0    190677.0       57082.0
# Jackson       MS           133186.0    186318.0       53132.0
# Huntington    WV            98628.0    126746.0       28118.0
#
#                          Overall % increase
# RegionName    StateName
# Oklahoma City OK                      43.30
# Little Rock   AR                      34.13
# Wichita       KS                      42.73
# Jackson       MS                      39.89
# Huntington    WV                      28.51

# %% [markdown]
# There are no surprises in either the five metro areas with the highest mid-tier home values, nor the five with the lowest. The highest is the LA/Long Beach/Anaheim metro area, with home values approaching $1 million, and the other areas are also known for having higher costs of living as well. The bottom five are metro areas of Southern states, where the cost of living is traditionally lower.
#
# With an overview of how home values have changed over time, let's examine two more pieces of data: home inventory levels and how fast homes are selling. This will paint a more complete picture of how else the housing market has been affected during the pandemic. We'll start with housing inventory.

# %%
#Examine the housing inventory dataframe
inventory_metro.head(3)
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
#
#   StateName  2018-01-31  2018-02-28  2018-03-31  2018-04-30  2018-05-31  ...  \
# 0       NaN   1424597.0   1381971.0   1438966.0   1525925.0   1627554.0  ...
# 1        NY     68792.0     68338.0     72824.0     79740.0     85755.0  ...
# 2        CA     20002.0     19836.0     21790.0     23704.0     25665.0  ...
#
#    2021-09-30  2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# 0   1135210.0   1126131.0   1062440.0    948819.0    823835.0    725043.0
# 1     63578.0     61886.0     58322.0     52225.0     44757.0     39560.0
# 2     21430.0     20457.0     18589.0     15824.0     13528.0     12563.0
#
#    2022-03-31  2022-04-30  2022-05-31  2022-06-30
# 0    715583.0    739448.0    807373.0    879047.0
# 1     39507.0     41517.0     44808.0     47371.0
# 2     13620.0     14831.0     16363.0     17894.0
#
# [3 rows x 59 columns]

# %%
#Format the inventory_metro dataframe similarly to the home_metro dataframe

#Creating a function to apply to the other dataframes
def format_df(df):
    df = df.iloc[1:]
    df = df.drop(['RegionID','RegionType'],axis=1)
    df.loc[:,'RegionName'] = df.loc[:,'RegionName'].str.split(',').str[0]
    df = df.sort_values('SizeRank')
    df = df.groupby(by='StateName',as_index=False).apply(lambda x:x.head(1))
    df = df.drop(['SizeRank'],axis=1)
    df = df.set_index(['RegionName','StateName'])
    df.columns = pd.to_datetime(df.columns)
    return df

#Applying function to inventory dataset
inventory_metro = format_df(inventory_metro)

#Dates from 2018 forward
inventory_metro = inventory_metro.loc[:,inventory_metro.columns>='2018-01-31']

inventory_metro.head(3)
# Out:
#                        2018-01-31  2018-02-28  2018-03-31  2018-04-30  \
# RegionName  StateName
# Anchorage   AK             1836.0      1777.0      1896.0      2044.0
# Birmingham  AL             6250.0      6176.0      6423.0      6732.0
# Little Rock AR             4934.0      4794.0      4947.0      5195.0
#
#                        2018-05-31  2018-06-30  2018-07-31  2018-08-31  \
# RegionName  StateName
# Anchorage   AK             2240.0      2415.0      2577.0      2662.0
# Birmingham  AL             7009.0      7235.0      7295.0      7308.0
# Little Rock AR             5553.0      5806.0      5917.0      5977.0
#
#                        2018-09-30  2018-10-31  ...  2021-09-30  2021-10-31  \
# RegionName  StateName                          ...
# Anchorage   AK             2605.0      2481.0  ...      1695.0      1590.0
# Birmingham  AL             7181.0      7042.0  ...      4222.0      4166.0
# Little Rock AR             5945.0      5889.0  ...      3304.0      3288.0
#
#                        2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# RegionName  StateName
# Anchorage   AK             1352.0      1091.0       849.0       737.0
# Birmingham  AL             3933.0      3620.0      3283.0      3015.0
# Little Rock AR             3127.0      2856.0      2547.0      2254.0
#
#                        2022-03-31  2022-04-30  2022-05-31  2022-06-30
# RegionName  StateName
# Anchorage   AK              739.0       850.0       995.0      1167.0
# Birmingham  AL             2984.0      3010.0      3131.0      3292.0
# Little Rock AR             2196.0      2228.0      2375.0      2474.0
#
# [3 rows x 54 columns]

# %%
#Check for missing values
inventory_metro.isna().any().sum()
# Out:
# 0

# %%
#Get inventory change over time
inventory_metro_new = inventory_metro.loc[:,['2018-01-31','2022-06-30']]
inventory_metro_new['Inventory Change']= inventory_metro_new.iloc[:,1]-inventory_metro_new.iloc[:,0]
inventory_metro_new['Overall % increase'] = round(100*(inventory_metro_new.iloc[:,1]-inventory_metro_new.iloc[:,0])/inventory_metro_new.iloc[:,0],2)
inventory_metro_new = inventory_metro_new.sort_values('Overall % increase',ascending = False)
inventory_metro_new
# Out:
#                                           2018-01-31 00:00:00  \
# RegionName                     StateName
# Seattle                        WA                      7696.0
# Minneapolis-St Paul            MN                     10307.0
# Sioux Falls                    SD                      1066.0
# Los Angeles-Long Beach-Anaheim CA                     20002.0
# Portland                       OR                      7657.0
# Salt Lake City                 UT                      2586.0
# Boston                         MA                     10400.0
# Detroit                        MI                     15149.0
# Denver                         CO                     10508.0
# Indianapolis                   IN                      7240.0
# Boise City                     ID                      3485.0
# Manchester                     NH                       968.0
# Omaha                          NE                      3034.0
# Dallas-Fort Worth              TX                     24271.0
# Phoenix                        AZ                     25674.0
# Louisville-Jefferson County    KY                      4492.0
# Milwaukee                      WI                      4071.0
# Washington                     DC                     22337.0
# Las Vegas                      NV                     11907.0
# Fargo                          ND                       977.0
# New York                       NY                     68792.0
# Burlington                     VT                       558.0
# Des Moines                     IA                      3789.0
# Billings                       MT                       746.0
# Cheyenne                       WY                       487.0
# Chicago                        IL                     42638.0
# Anchorage                      AK                      1836.0
# Atlanta                        GA                     29702.0
# Urban Honolulu                 HI                      3623.0
# Nashville                      TN                      8652.0
# Philadelphia                   PA                     26448.0
# Trenton                        NJ                      1527.0
# New Orleans                    LA                      3839.0
# Charlotte                      NC                     10098.0
# Cincinnati                     OH                      8145.0
# Portland                       ME                      2197.0
# Baltimore                      MD                     12986.0
# St. Louis                      MO                     12915.0
# Wichita                        KS                      2686.0
# Birmingham                     AL                      6250.0
# Virginia Beach                 VA                     11848.0
# Albuquerque                    NM                      3815.0
# Little Rock                    AR                      4934.0
# Providence                     RI                      5971.0
# Jackson                        MS                      2813.0
# Oklahoma City                  OK                      8536.0
# Hartford                       CT                      5874.0
# Huntington                     WV                      1773.0
# Miami-Fort Lauderdale          FL                     59766.0
# Greenville                     SC                      6111.0
# Salisbury                      DE                      5253.0
#
#                                           2022-06-30 00:00:00  \
# RegionName                     StateName
# Seattle                        WA                      9943.0
# Minneapolis-St Paul            MN                     10583.0
# Sioux Falls                    SD                       969.0
# Los Angeles-Long Beach-Anaheim CA                     17894.0
# Portland                       OR                      6842.0
# Salt Lake City                 UT                      2310.0
# Boston                         MA                      8947.0
# Detroit                        MI                     12620.0
# Denver                         CO                      8709.0
# Indianapolis                   IN                      5746.0
# Boise City                     ID                      2744.0
# Manchester                     NH                       751.0
# Omaha                          NE                      2347.0
# Dallas-Fort Worth              TX                     18772.0
# Phoenix                        AZ                     19367.0
# Louisville-Jefferson County    KY                      3351.0
# Milwaukee                      WI                      2988.0
# Washington                     DC                     16168.0
# Las Vegas                      NV                      8497.0
# Fargo                          ND                       682.0
# New York                       NY                     47371.0
# Burlington                     VT                       379.0
# Des Moines                     IA                      2528.0
# Billings                       MT                       497.0
# Cheyenne                       WY                       319.0
# Chicago                        IL                     27803.0
# Anchorage                      AK                      1167.0
# Atlanta                        GA                     18814.0
# Urban Honolulu                 HI                      2280.0
# Nashville                      TN                      5362.0
# Philadelphia                   PA                     16114.0
# Trenton                        NJ                       929.0
# New Orleans                    LA                      2335.0
# Charlotte                      NC                      6099.0
# Cincinnati                     OH                      4897.0
# Portland                       ME                      1289.0
# Baltimore                      MD                      7452.0
# St. Louis                      MO                      7098.0
# Wichita                        KS                      1416.0
# Birmingham                     AL                      3292.0
# Virginia Beach                 VA                      6208.0
# Albuquerque                    NM                      1913.0
# Little Rock                    AR                      2474.0
# Providence                     RI                      2928.0
# Jackson                        MS                      1361.0
# Oklahoma City                  OK                      4089.0
# Hartford                       CT                      2482.0
# Huntington                     WV                       746.0
# Miami-Fort Lauderdale          FL                     23454.0
# Greenville                     SC                      2284.0
# Salisbury                      DE                      1863.0
#
#                                           Inventory Change  Overall % increase
# RegionName                     StateName
# Seattle                        WA                   2247.0               29.20
# Minneapolis-St Paul            MN                    276.0                2.68
# Sioux Falls                    SD                    -97.0               -9.10
# Los Angeles-Long Beach-Anaheim CA                  -2108.0              -10.54
# Portland                       OR                   -815.0              -10.64
# Salt Lake City                 UT                   -276.0              -10.67
# Boston                         MA                  -1453.0              -13.97
# Detroit                        MI                  -2529.0              -16.69
# Denver                         CO                  -1799.0              -17.12
# Indianapolis                   IN                  -1494.0              -20.64
# Boise City                     ID                   -741.0              -21.26
# Manchester                     NH                   -217.0              -22.42
# Omaha                          NE                   -687.0              -22.64
# Dallas-Fort Worth              TX                  -5499.0              -22.66
# Phoenix                        AZ                  -6307.0              -24.57
# Louisville-Jefferson County    KY                  -1141.0              -25.40
# Milwaukee                      WI                  -1083.0              -26.60
# Washington                     DC                  -6169.0              -27.62
# Las Vegas                      NV                  -3410.0              -28.64
# Fargo                          ND                   -295.0              -30.19
# New York                       NY                 -21421.0              -31.14
# Burlington                     VT                   -179.0              -32.08
# Des Moines                     IA                  -1261.0              -33.28
# Billings                       MT                   -249.0              -33.38
# Cheyenne                       WY                   -168.0              -34.50
# Chicago                        IL                 -14835.0              -34.79
# Anchorage                      AK                   -669.0              -36.44
# Atlanta                        GA                 -10888.0              -36.66
# Urban Honolulu                 HI                  -1343.0              -37.07
# Nashville                      TN                  -3290.0              -38.03
# Philadelphia                   PA                 -10334.0              -39.07
# Trenton                        NJ                   -598.0              -39.16
# New Orleans                    LA                  -1504.0              -39.18
# Charlotte                      NC                  -3999.0              -39.60
# Cincinnati                     OH                  -3248.0              -39.88
# Portland                       ME                   -908.0              -41.33
# Baltimore                      MD                  -5534.0              -42.62
# St. Louis                      MO                  -5817.0              -45.04
# Wichita                        KS                  -1270.0              -47.28
# Birmingham                     AL                  -2958.0              -47.33
# Virginia Beach                 VA                  -5640.0              -47.60
# Albuquerque                    NM                  -1902.0              -49.86
# Little Rock                    AR                  -2460.0              -49.86
# Providence                     RI                  -3043.0              -50.96
# Jackson                        MS                  -1452.0              -51.62
# Oklahoma City                  OK                  -4447.0              -52.10
# Hartford                       CT                  -3392.0              -57.75
# Huntington                     WV                  -1027.0              -57.92
# Miami-Fort Lauderdale          FL                 -36312.0              -60.76
# Greenville                     SC                  -3827.0              -62.62
# Salisbury                      DE                  -3390.0              -64.53

# %% [markdown]
# We see a net decrease in available houses on the market in every large metro area, except Seattle, Washington, and the Minneapolis-St. Paul, Minnesota metro areas. However, even for these 2 metro areas, the increase in houses that are available is modest. Once again, let's do a year by year percent increase to further break this down.

# %%
#Group by year, then calculate percent increase
inventory_year = inventory_metro.groupby(inventory_metro.columns.year,axis=1).mean()
inventory_year_pct = (round(inventory_year.transpose().pct_change(),2)*100).transpose()
inventory_year_pct
# Out:
#                                           2018  2019  2020  2021  2022
# RegionName                     StateName
# Anchorage                      AK          NaN  -9.0 -18.0 -17.0 -36.0
# Birmingham                     AL          NaN  -7.0 -15.0 -25.0 -23.0
# Little Rock                    AR          NaN  -7.0 -14.0 -33.0 -21.0
# Phoenix                        AZ          NaN   0.0 -18.0 -16.0  -9.0
# Los Angeles-Long Beach-Anaheim CA          NaN  10.0 -19.0 -15.0 -26.0
# Denver                         CO          NaN  15.0 -16.0 -42.0 -22.0
# Hartford                       CT          NaN  -4.0 -22.0 -30.0 -38.0
# Washington                     DC          NaN -10.0 -18.0  -4.0 -26.0
# Salisbury                      DE          NaN  -2.0 -21.0 -42.0 -28.0
# Miami-Fort Lauderdale          FL          NaN   4.0  -9.0 -36.0 -38.0
# Atlanta                        GA          NaN  13.0  -7.0 -32.0 -26.0
# Urban Honolulu                 HI          NaN  14.0  -9.0 -32.0 -23.0
# Des Moines                     IA          NaN   2.0  -9.0 -19.0 -23.0
# Boise City                     ID          NaN   5.0 -18.0 -15.0 -21.0
# Chicago                        IL          NaN   6.0 -13.0 -23.0 -32.0
# Indianapolis                   IN          NaN   3.0 -15.0 -11.0 -19.0
# Wichita                        KS          NaN  -7.0 -19.0 -22.0 -25.0
# Louisville-Jefferson County    KY          NaN   6.0 -20.0 -14.0 -19.0
# New Orleans                    LA          NaN   1.0 -21.0 -26.0 -19.0
# Boston                         MA          NaN   9.0 -18.0 -20.0 -33.0
# Baltimore                      MD          NaN  -2.0 -25.0 -21.0 -21.0
# Portland                       ME          NaN   3.0 -19.0 -24.0 -42.0
# Detroit                        MI          NaN  12.0 -17.0 -20.0 -20.0
# Minneapolis-St Paul            MN          NaN   5.0  -9.0 -13.0 -24.0
# St. Louis                      MO          NaN  -7.0 -17.0 -24.0 -27.0
# Jackson                        MS          NaN  -7.0 -18.0 -37.0 -19.0
# Billings                       MT          NaN  -0.0 -28.0 -23.0 -28.0
# Charlotte                      NC          NaN  11.0 -17.0 -31.0 -29.0
# Fargo                          ND          NaN   5.0 -10.0 -23.0 -33.0
# Omaha                          NE          NaN   0.0 -11.0 -24.0 -22.0
# Manchester                     NH          NaN   5.0 -20.0 -23.0 -33.0
# Trenton                        NJ          NaN   1.0 -27.0 -21.0 -27.0
# Albuquerque                    NM          NaN  -9.0 -21.0 -22.0 -28.0
# Las Vegas                      NV          NaN  17.0 -17.0 -26.0 -17.0
# New York                       NY          NaN   5.0 -14.0 -19.0 -29.0
# Cincinnati                     OH          NaN  -2.0 -20.0 -20.0 -22.0
# Oklahoma City                  OK          NaN -11.0 -16.0 -26.0 -20.0
# Portland                       OR          NaN   9.0 -17.0 -20.0 -24.0
# Philadelphia                   PA          NaN  -2.0 -24.0 -15.0 -22.0
# Providence                     RI          NaN   0.0 -22.0 -35.0 -32.0
# Greenville                     SC          NaN   5.0 -12.0 -43.0 -33.0
# Sioux Falls                    SD          NaN   3.0  -6.0  -2.0 -28.0
# Nashville                      TN          NaN  17.0  -7.0 -44.0 -33.0
# Dallas-Fort Worth              TX          NaN  17.0 -10.0 -24.0 -28.0
# Salt Lake City                 UT          NaN  18.0 -23.0 -27.0 -35.0
# Virginia Beach                 VA          NaN  -6.0 -21.0 -22.0 -26.0
# Burlington                     VT          NaN  16.0 -17.0 -26.0 -44.0
# Seattle                        WA          NaN   9.0 -21.0  -6.0 -26.0
# Milwaukee                      WI          NaN -10.0  -6.0   0.0 -30.0
# Huntington                     WV          NaN  -8.0 -21.0 -38.0 -14.0
# Cheyenne                       WY          NaN -18.0  -1.0 -27.0 -18.0

# %% [markdown]
# At a glance, housing inventory for some metro areas increased and some decreased from 2018-2019, but after that there seems to be a decrease across the board. Quantifying how many metros had an inventory increase per year:

# %%
print('2018-2019: ',inventory_year_pct.loc[(inventory_year_pct[2019] > 0),:].index.nunique())
print('2019-2020: ',inventory_year_pct.loc[(inventory_year_pct[2020] > 0),:].index.nunique())
print('2020-2021: ',inventory_year_pct.loc[(inventory_year_pct[2021] > 0),:].index.nunique())
print('2021-2022: ',inventory_year_pct.loc[(inventory_year_pct[2022] > 0),:].index.nunique())
# Out:
# 2018-2019:  29
# 2019-2020:  0
# 2020-2021:  0
# 2021-2022:  0

# %% [markdown]
# There were 29 states where the number of houses available increased from 2018-2019. After this time period, all metro areas had a decrease for the next several years.
#
# The last piece of the puzzle we will investigate is the time it takes for houses to go under contrat (in "pending" status on Zillow).

# %%
pending_metro.head(3)
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
#
#   StateName  2018-03-31  2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  \
# 0       NaN        30.0        22.0        20.0        20.0        22.0  ...
# 1        NY        46.0        36.0        35.0        36.0        39.0  ...
# 2        CA        17.0        15.0        16.0        16.0        18.0  ...
#
#    2021-09-30  2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# 0        10.0        11.0        11.0        13.0        13.0        11.0
# 1        30.0        31.0        34.0        36.0        42.0        38.0
# 2        13.0        13.0        13.0        13.0        13.0        12.0
#
#    2022-03-31  2022-04-30  2022-05-31  2022-06-30
# 0         9.0         7.0         7.0         7.0
# 1        31.0        22.0        20.0        21.0
# 2        11.0        10.0        11.0        12.0
#
# [3 rows x 57 columns]

# %%
#Format the dataframe using the previously defined function
pending_metro = format_df(pending_metro)

#Dates from 2018 forward, dataset starts in March
pending_metro = pending_metro.loc[:,pending_metro.columns>='2018-03-31']

pending_metro.head(3)
# Out:
#                        2018-03-31  2018-04-30  2018-05-31  2018-06-30  \
# RegionName  StateName
# Anchorage   AK               36.0        23.0        22.0        23.0
# Birmingham  AL               24.0        15.0        13.0        14.0
# Little Rock AR               50.0        43.0        38.0        40.0
#
#                        2018-07-31  2018-08-31  2018-09-30  2018-10-31  \
# RegionName  StateName
# Anchorage   AK               25.0        30.0        36.0        45.0
# Birmingham  AL               16.0        19.0        22.0        25.0
# Little Rock AR               43.0        45.0        45.0        46.0
#
#                        2018-11-30  2018-12-31  ...  2021-09-30  2021-10-31  \
# RegionName  StateName                          ...
# Anchorage   AK               52.0        62.0  ...         9.0        12.0
# Birmingham  AL               26.0        29.0  ...         6.0         6.0
# Little Rock AR               51.0        59.0  ...        12.0        14.0
#
#                        2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# RegionName  StateName
# Anchorage   AK               14.0        14.0        11.0         8.0
# Birmingham  AL                6.0         6.0         6.0         8.0
# Little Rock AR               15.0        18.0        18.0        15.0
#
#                        2022-03-31  2022-04-30  2022-05-31  2022-06-30
# RegionName  StateName
# Anchorage   AK                5.0         4.0         4.0         5.0
# Birmingham  AL                8.0         7.0         5.0         5.0
# Little Rock AR               10.0         8.0         7.0         7.0
#
# [3 rows x 52 columns]

# %%
#Check for missing values
pending_metro.isna().any().sum()
# Out:
# 39

# %%
#Display all NaNs
pending_metro.loc[pending_metro.isna().any(axis=1),pending_metro.isna().any(axis=0)]
# Out:
#                       2018-03-31  2018-04-30  2018-05-31  2018-06-30  \
# RegionName StateName
# Fargo      ND                NaN         NaN         NaN         NaN
# Huntington WV                NaN         NaN         NaN         NaN
#
#                       2018-07-31  2018-08-31  2018-09-30  2018-10-31  \
# RegionName StateName
# Fargo      ND                NaN         NaN         NaN         NaN
# Huntington WV                NaN         NaN         NaN         NaN
#
#                       2018-11-30  2018-12-31  ...  2020-08-31  2020-09-30  \
# RegionName StateName                          ...
# Fargo      ND                NaN         NaN  ...         NaN         NaN
# Huntington WV                NaN         NaN  ...        33.0        28.0
#
#                       2020-10-31  2020-11-30  2020-12-31  2021-01-31  \
# RegionName StateName
# Fargo      ND                NaN         NaN         NaN         NaN
# Huntington WV               23.0        24.0        24.0        34.0
#
#                       2021-02-28  2021-03-31  2021-04-30  2021-05-31
# RegionName StateName
# Fargo      ND                NaN         NaN         NaN         NaN
# Huntington WV               36.0        34.0        20.0        15.0
#
# [2 rows x 39 columns]

# %% [markdown]
# All missing values in this dataset belong to either Fargo, North Dakota or Huntington, West Virginia. Based on the amount of data missing for both metro areas, these can be dropped entirely.

# %%
#Drop Fargo and Huntington 
pending_metro = pending_metro.drop(['Huntington','Fargo'],level='RegionName', axis=0)

#Check again for nulls
pending_metro.isna().any().sum()
# Out:
# 0

# %%
#Get change over time in number of days to pending
pending_metro_new = pending_metro.loc[:,['2018-03-31','2022-06-30']]
pending_metro_new['Days to Pending Change']= pending_metro_new.iloc[:,1]-pending_metro_new.iloc[:,0]
pending_metro_new['Overall % increase'] = round(100*(pending_metro_new.iloc[:,1]-pending_metro_new.iloc[:,0])/pending_metro_new.iloc[:,0],2)
pending_metro_new = pending_metro_new.sort_values('Overall % increase',ascending = False)
pending_metro_new
# Out:
#                                           2018-03-31 00:00:00  \
# RegionName                     StateName
# Milwaukee                      WI                        18.0
# Seattle                        WA                         7.0
# Denver                         CO                         6.0
# Los Angeles-Long Beach-Anaheim CA                        17.0
# Salt Lake City                 UT                        11.0
# Boise City                     ID                        15.0
# Boston                         MA                        15.0
# New York                       NY                        46.0
# Portland                       OR                        15.0
# Atlanta                        GA                        20.0
# Minneapolis-St Paul            MN                        26.0
# Phoenix                        AZ                        29.0
# Detroit                        MI                        19.0
# Urban Honolulu                 HI                        38.0
# Manchester                     NH                        19.0
# Miami-Fort Lauderdale          FL                        42.0
# Omaha                          NE                        14.0
# Trenton                        NJ                        41.0
# Charlotte                      NC                        15.0
# Las Vegas                      NV                        31.0
# Cheyenne                       WY                        21.0
# Portland                       ME                        30.0
# Virginia Beach                 VA                        60.0
# Chicago                        IL                        30.0
# Louisville-Jefferson County    KY                        22.0
# Dallas-Fort Worth              TX                        28.0
# Birmingham                     AL                        24.0
# Nashville                      TN                        24.0
# Philadelphia                   PA                        34.0
# Providence                     RI                        41.0
# Cincinnati                     OH                        17.0
# Des Moines                     IA                        29.0
# Salisbury                      DE                        58.0
# New Orleans                    LA                        41.0
# Greenville                     SC                        24.0
# Washington                     DC                        37.0
# Indianapolis                   IN                        25.0
# Burlington                     VT                        38.0
# Baltimore                      MD                        38.0
# St. Louis                      MO                        32.0
# Little Rock                    AR                        50.0
# Anchorage                      AK                        36.0
# Albuquerque                    NM                        30.0
# Rapid City                     SD                        39.0
# Billings                       MT                        44.0
# Hartford                       CT                        53.0
# Oklahoma City                  OK                        36.0
# Wichita                        KS                        36.0
# Jackson                        MS                        47.0
#
#                                           2022-06-30 00:00:00  \
# RegionName                     StateName
# Milwaukee                      WI                        19.0
# Seattle                        WA                         6.0
# Denver                         CO                         5.0
# Los Angeles-Long Beach-Anaheim CA                        12.0
# Salt Lake City                 UT                         6.0
# Boise City                     ID                         8.0
# Boston                         MA                         7.0
# New York                       NY                        21.0
# Portland                       OR                         6.0
# Atlanta                        GA                         7.0
# Minneapolis-St Paul            MN                         9.0
# Phoenix                        AZ                        10.0
# Detroit                        MI                         6.0
# Urban Honolulu                 HI                        12.0
# Manchester                     NH                         6.0
# Miami-Fort Lauderdale          FL                        12.0
# Omaha                          NE                         4.0
# Trenton                        NJ                        11.0
# Charlotte                      NC                         4.0
# Las Vegas                      NV                         8.0
# Cheyenne                       WY                         5.0
# Portland                       ME                         7.0
# Virginia Beach                 VA                        14.0
# Chicago                        IL                         7.0
# Louisville-Jefferson County    KY                         5.0
# Dallas-Fort Worth              TX                         6.0
# Birmingham                     AL                         5.0
# Nashville                      TN                         5.0
# Philadelphia                   PA                         7.0
# Providence                     RI                         8.0
# Cincinnati                     OH                         3.0
# Des Moines                     IA                         5.0
# Salisbury                      DE                        10.0
# New Orleans                    LA                         7.0
# Greenville                     SC                         4.0
# Washington                     DC                         6.0
# Indianapolis                   IN                         4.0
# Burlington                     VT                         6.0
# Baltimore                      MD                         6.0
# St. Louis                      MO                         5.0
# Little Rock                    AR                         7.0
# Anchorage                      AK                         5.0
# Albuquerque                    NM                         4.0
# Rapid City                     SD                         5.0
# Billings                       MT                         5.0
# Hartford                       CT                         6.0
# Oklahoma City                  OK                         4.0
# Wichita                        KS                         4.0
# Jackson                        MS                         5.0
#
#                                           Days to Pending Change  \
# RegionName                     StateName
# Milwaukee                      WI                            1.0
# Seattle                        WA                           -1.0
# Denver                         CO                           -1.0
# Los Angeles-Long Beach-Anaheim CA                           -5.0
# Salt Lake City                 UT                           -5.0
# Boise City                     ID                           -7.0
# Boston                         MA                           -8.0
# New York                       NY                          -25.0
# Portland                       OR                           -9.0
# Atlanta                        GA                          -13.0
# Minneapolis-St Paul            MN                          -17.0
# Phoenix                        AZ                          -19.0
# Detroit                        MI                          -13.0
# Urban Honolulu                 HI                          -26.0
# Manchester                     NH                          -13.0
# Miami-Fort Lauderdale          FL                          -30.0
# Omaha                          NE                          -10.0
# Trenton                        NJ                          -30.0
# Charlotte                      NC                          -11.0
# Las Vegas                      NV                          -23.0
# Cheyenne                       WY                          -16.0
# Portland                       ME                          -23.0
# Virginia Beach                 VA                          -46.0
# Chicago                        IL                          -23.0
# Louisville-Jefferson County    KY                          -17.0
# Dallas-Fort Worth              TX                          -22.0
# Birmingham                     AL                          -19.0
# Nashville                      TN                          -19.0
# Philadelphia                   PA                          -27.0
# Providence                     RI                          -33.0
# Cincinnati                     OH                          -14.0
# Des Moines                     IA                          -24.0
# Salisbury                      DE                          -48.0
# New Orleans                    LA                          -34.0
# Greenville                     SC                          -20.0
# Washington                     DC                          -31.0
# Indianapolis                   IN                          -21.0
# Burlington                     VT                          -32.0
# Baltimore                      MD                          -32.0
# St. Louis                      MO                          -27.0
# Little Rock                    AR                          -43.0
# Anchorage                      AK                          -31.0
# Albuquerque                    NM                          -26.0
# Rapid City                     SD                          -34.0
# Billings                       MT                          -39.0
# Hartford                       CT                          -47.0
# Oklahoma City                  OK                          -32.0
# Wichita                        KS                          -32.0
# Jackson                        MS                          -42.0
#
#                                           Overall % increase
# RegionName                     StateName
# Milwaukee                      WI                       5.56
# Seattle                        WA                     -14.29
# Denver                         CO                     -16.67
# Los Angeles-Long Beach-Anaheim CA                     -29.41
# Salt Lake City                 UT                     -45.45
# Boise City                     ID                     -46.67
# Boston                         MA                     -53.33
# New York                       NY                     -54.35
# Portland                       OR                     -60.00
# Atlanta                        GA                     -65.00
# Minneapolis-St Paul            MN                     -65.38
# Phoenix                        AZ                     -65.52
# Detroit                        MI                     -68.42
# Urban Honolulu                 HI                     -68.42
# Manchester                     NH                     -68.42
# Miami-Fort Lauderdale          FL                     -71.43
# Omaha                          NE                     -71.43
# Trenton                        NJ                     -73.17
# Charlotte                      NC                     -73.33
# Las Vegas                      NV                     -74.19
# Cheyenne                       WY                     -76.19
# Portland                       ME                     -76.67
# Virginia Beach                 VA                     -76.67
# Chicago                        IL                     -76.67
# Louisville-Jefferson County    KY                     -77.27
# Dallas-Fort Worth              TX                     -78.57
# Birmingham                     AL                     -79.17
# Nashville                      TN                     -79.17
# Philadelphia                   PA                     -79.41
# Providence                     RI                     -80.49
# Cincinnati                     OH                     -82.35
# Des Moines                     IA                     -82.76
# Salisbury                      DE                     -82.76
# New Orleans                    LA                     -82.93
# Greenville                     SC                     -83.33
# Washington                     DC                     -83.78
# Indianapolis                   IN                     -84.00
# Burlington                     VT                     -84.21
# Baltimore                      MD                     -84.21
# St. Louis                      MO                     -84.38
# Little Rock                    AR                     -86.00
# Anchorage                      AK                     -86.11
# Albuquerque                    NM                     -86.67
# Rapid City                     SD                     -87.18
# Billings                       MT                     -88.64
# Hartford                       CT                     -88.68
# Oklahoma City                  OK                     -88.89
# Wichita                        KS                     -88.89
# Jackson                        MS                     -89.36

# %% [markdown]
# Similar to previous analysis of the other datasets, there is a decrease in sale time for houses on the market for almost all states. The one exception is Milwaukee, Wisconsin; however, the number of days for this city only increased by 1 from 2018 to 2022. Assuming previous patterns hold, we would see a dramatic percent decrease in time on the market from 2019-2020 for most states, and then another (less dramatic) dip from 2021-2022.
#
# Let's check if this is true by calculating the overall average time on the market per year:

# %%
#Getting average number of days on market per year
pending_metro.groupby(pending_metro.columns.year, axis=1).mean().mean()
# Out:
# 2018    25.677551
# 2019    28.217687
# 2020    20.603741
# 2021    10.685374
# 2022     8.690476
# dtype: float64

# %% [markdown]
# As we suspected, the average number of days a house was on the market was increasing before the pandemic, after which it began to rapidly decline. Buyers searching pre-pandemic had on average over 25 days before a house went under contract, and now this has dropped to single digits.
#
# Last, let's find the metro areas with the longest and the shortest turn around times.

# %%
pending_metro.loc[:,'2022-06-30'].describe()
# Out:
# count    49.000000
# mean      7.122449
# std       3.643674
# min       3.000000
# 25%       5.000000
# 50%       6.000000
# 75%       8.000000
# max      21.000000
# Name: 2022-06-30 00:00:00, dtype: float64

# %%
#Finding metro with shortest turnaround time based on describe above
pending_metro.loc[pending_metro.loc[:,'2022-06-30']==3,'2022-06-30']
# Out:
# RegionName  StateName
# Cincinnati  OH           3.0
# Name: 2022-06-30 00:00:00, dtype: float64

# %%
#Finding metro with longest turnaround time
pending_metro.loc[pending_metro.loc[:,'2022-06-30']==21,'2022-06-30']
# Out:
# RegionName  StateName
# New York    NY           21.0
# Name: 2022-06-30 00:00:00, dtype: float64

# %% [markdown]
# Cincinnati, Ohio is down to three days as of the end of June 2022. At this number of days, buyers would likely have to put down an offer almost as soon as they view a home to have any chance of acceptance. Meanwhile, New York City is at 21 days, a little under half of the time from before the pandemic.
#
# Another interesting facet of this data is that even at the upper 75th percentile of days on the market, this only amounts to eight days. This then leaves any metro areas with double digit days in this upper percentile.

# %% [markdown]
# Using data from Zillow, we have managed to paint a clear picture of how the housing market boomed during the pandemic. Before 2020, housing prices were increasing at a modest pace, homes were more available, and homes were generally on the market for several weeks before going under contract. During and after 2020 the housing situation changed drastically, leaving many families unable to buy. Housing prices shot up in the period from 2020-2021, in some markets even doubling, while the average time a home was on the market went down to typically under a week. Furthermore, housing inventory has declined considerably. While price increases have slowed and inventory has picked up, the market has not yet stabilized and housing metrics continue to move in an undesirable direction.
#
# If we were to expand this project further, a signficant area of interest would be the rental market, the data for which is also available on Zillow. Renting is increasing across the country, and a future project would want to quantify this increase exactly, and determine which markets have been the most affected. These datasets could be tied into wage data available via the U.S. Census. This would allow a better understand how affordable housing is given the average family's income, per state or metro area.
